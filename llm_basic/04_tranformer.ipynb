# %% [markdown]
# # Transformer (read any of them)
# - Theory: https://www.youtube.com/watch?v=bCz4OMemCcA&t=1764s
# - Code: https://www.youtube.com/watch?v=ISNdQcPhsts
# - Blog: https://jalammar.github.io/illustrated-transformer/
